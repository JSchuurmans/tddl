# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from pathlib import Path
import pandas as pd
import numpy as np

import seaborn as sns
sns.set_theme(style="darkgrid")

logdir = Path("/bigdata/cifar10/logs/garipov/dbs/")

# %%
import os

folders = os.listdir(logdir)
print(f"number of folders: {len(folders)}")
# Out:
# number of folders: 14

# %%
from tddl.post_processing.path_utils import logdir_to_paths

paths = logdir_to_paths(logdir)

print(len(paths))
# Out:
# 5

# %%
# baseline

baseline_path = Path("/bigdata/cifar10/logs/garipov/baselines/1647358615/gar_18_dNone_128_sgd_l0.1_g0.1_w0.0_sTrue")
# baseline_model = torch.load(baseline_path / "cnn_best.pth")
with open(baseline_path/'results.json') as json_file:
    baseline_result = json.load(json_file)
baseline_result
# Out:
# {'best_epoch': 38,
#  'best_train_acc': 0.9749333333333333,
#  'best_valid_acc': 0.9078,
#  'best_valid_loss': 0.003568341651931405,
#  'test_acc': 0.891,
#  'test_loss': 0.004007616302371025,
#  'n_param': 557642,
#  'model_name': 'gar_18_dNone_128_sgd_l0.1_g0.1_w0.0_sTrue'}

# %%
from tddl.post_processing.post_dbs import process_factorized_networks

process_factorized_networks(paths, baseline_path)

# %%
from tddl.post_processing.path_utils import paths_to_df

df = paths_to_df(paths, filename='results_dbs.json', dbs=True)
df['compression'] = 'dbs'
df
# Out:
#   name  nr            layers factorization  rank  valid_acc  \
# 0   []  []  [2, 4, 6, 8, 10]        tucker  0.10     0.8202
# 1   []  []  [2, 4, 6, 8, 10]        tucker  0.75     0.9040
# 2   []  []  [2, 4, 6, 8, 10]        tucker  0.90     0.9016
# 3   []  []  [2, 4, 6, 8, 10]        tucker  0.25     0.8778
# 4   []  []  [2, 4, 6, 8, 10]        tucker  0.50     0.8946
#
#    valid_acc_before_ft  test_acc_before_ft  n_param_fact  test_acc      lr  \
# 0               0.3504              0.3384         63279    0.8102  0.0001
# 1               0.8984              0.8853        426342    0.8906  0.0001
# 2               0.8992              0.8874        507466    0.8904  0.0001
# 3               0.8150              0.8042        144777    0.8726  0.0001
# 4               0.8784              0.8717        283581    0.8837  0.0001
#
#   optimizer  baseline_parameters  fact_parameters  compression_ratio  \
# 0       sgd               557642            63279           0.113476
# 1       sgd               557642           426342           0.764544
# 2       sgd               557642           507466           0.910021
# 3       sgd               557642           144777           0.259624
# 4       sgd               557642           283581           0.508536
#
#   compression
# 0         dbs
# 1         dbs
# 2         dbs
# 3         dbs
# 4         dbs

# %%
logdir_constant = Path("/bigdata/cifar10/logs/garipov/constant/")
folders_constant = os.listdir(logdir_constant)
paths_constant = logdir_to_paths(logdir_constant)

process_factorized_networks(paths_constant, baseline_path)

df_constant = paths_to_df(paths_constant, filename='results_dbs.json', dbs=True)
df_constant['compression'] = 'constant'
df_constant
# Out:
#   name  nr            layers factorization  rank  valid_acc  \
# 0   []  []  [2, 4, 6, 8, 10]        tucker  0.75     0.8984
# 1   []  []  [2, 4, 6, 8, 10]        tucker  0.25     0.8694
# 2   []  []  [2, 4, 6, 8, 10]        tucker  0.10     0.8138
# 3   []  []  [2, 4, 6, 8, 10]        tucker  0.50     0.8882
# 4   []  []  [2, 4, 6, 8, 10]        tucker  0.90     0.9036
#
#    valid_acc_before_ft  test_acc_before_ft  n_param_fact  test_acc      lr  \
# 0               0.8930              0.8808        422027    0.8873  0.0001
# 1               0.7736              0.7626        141971    0.8665  0.0001
# 2               0.3284              0.3196         60509    0.8050  0.0001
# 3               0.8676              0.8573        279154    0.8831  0.0001
# 4               0.8982              0.8861        501708    0.8891  0.0001
#
#   optimizer  baseline_parameters  fact_parameters  compression_ratio  \
# 0       sgd               557642           422027           0.756806
# 1       sgd               557642           141971           0.254592
# 2       sgd               557642            60509           0.108509
# 3       sgd               557642           279154           0.500597
# 4       sgd               557642           501708           0.899696
#
#   compression
# 0    constant
# 1    constant
# 2    constant
# 3    constant
# 4    constant

# %%
df = df.append(df_constant, ignore_index=True)
df
# Out:
#   name  nr            layers factorization  rank  valid_acc  \
# 0   []  []  [2, 4, 6, 8, 10]        tucker  0.10     0.8202
# 1   []  []  [2, 4, 6, 8, 10]        tucker  0.75     0.9040
# 2   []  []  [2, 4, 6, 8, 10]        tucker  0.90     0.9016
# 3   []  []  [2, 4, 6, 8, 10]        tucker  0.25     0.8778
# 4   []  []  [2, 4, 6, 8, 10]        tucker  0.50     0.8946
# 5   []  []  [2, 4, 6, 8, 10]        tucker  0.75     0.8984
# 6   []  []  [2, 4, 6, 8, 10]        tucker  0.25     0.8694
# 7   []  []  [2, 4, 6, 8, 10]        tucker  0.10     0.8138
# 8   []  []  [2, 4, 6, 8, 10]        tucker  0.50     0.8882
# 9   []  []  [2, 4, 6, 8, 10]        tucker  0.90     0.9036
#
#    valid_acc_before_ft  test_acc_before_ft  n_param_fact  test_acc      lr  \
# 0               0.3504              0.3384         63279    0.8102  0.0001
# 1               0.8984              0.8853        426342    0.8906  0.0001
# 2               0.8992              0.8874        507466    0.8904  0.0001
# 3               0.8150              0.8042        144777    0.8726  0.0001
# 4               0.8784              0.8717        283581    0.8837  0.0001
# 5               0.8930              0.8808        422027    0.8873  0.0001
# 6               0.7736              0.7626        141971    0.8665  0.0001
# 7               0.3284              0.3196         60509    0.8050  0.0001
# 8               0.8676              0.8573        279154    0.8831  0.0001
# 9               0.8982              0.8861        501708    0.8891  0.0001
#
#   optimizer  baseline_parameters  fact_parameters  compression_ratio  \
# 0       sgd               557642            63279           0.113476
# 1       sgd               557642           426342           0.764544
# 2       sgd               557642           507466           0.910021
# 3       sgd               557642           144777           0.259624
# 4       sgd               557642           283581           0.508536
# 5       sgd               557642           422027           0.756806
# 6       sgd               557642           141971           0.254592
# 7       sgd               557642            60509           0.108509
# 8       sgd               557642           279154           0.500597
# 9       sgd               557642           501708           0.899696
#
#   compression
# 0         dbs
# 1         dbs
# 2         dbs
# 3         dbs
# 4         dbs
# 5    constant
# 6    constant
# 7    constant
# 8    constant
# 9    constant

# %%
# df['rank'] = df['rank'].astype(float, copy=False)
# df['fact_rank'] = df['factorization'] + '-' + df['rank'].apply(str)
# df['fact_layers'] = df['factorization'] + '-' + df['layers'].apply(str)
# df['layers_fact'] = df['layers'].apply(str) + '-' + df['factorization'] 
# df.head()

# %%
df['test_error_before_ft'] = 1 - df.test_acc_before_ft
df['test_error'] = 1 - df.test_acc
df['valid_error_before_ft'] = 1 - df.valid_acc_before_ft
df['valid_error'] = 1 - df.valid_acc

df['log_test_error_before_ft'] = np.log(df.test_error_before_ft)
df['log_test_error'] = np.log(df.test_error)
df['log_valid_error_before_ft'] = np.log(df.valid_error_before_ft)
df['log_valid_error'] = np.log(df.valid_error)

# %%
# df = df.astype({
#     'layers':"category",
#     'fact_layers':"category",
#     'layers_fact':"category",
# })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_489552/402002624.py in <module>
# ----> 1 df = df.astype({
#       2     'layers':"category",
#       3     'fact_layers':"category",
#       4     'layers_fact':"category",
#       5 })
#
# ~/gitProjects/phd/tddl/venv/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5852             for col_name in dtype.keys():
#    5853                 if col_name not in self:
# -> 5854                     raise KeyError(
#    5855                         "Only a column name can be used for the "
#    5856                         "key in a dtype mappings argument."
#
# KeyError: 'Only a column name can be used for the key in a dtype mappings argument.'

# %% [markdown]
# # plots

# %%
import seaborn as sns
sns.set_theme()

# %%
df.columns
# Out:
# Index(['name', 'nr', 'layers', 'factorization', 'rank', 'valid_acc',
#        'valid_acc_before_ft', 'test_acc_before_ft', 'n_param_fact', 'test_acc',
#        'lr', 'optimizer', 'baseline_parameters', 'fact_parameters',
#        'compression_ratio', 'compression', 'test_error_before_ft',
#        'test_error', 'valid_error_before_ft', 'valid_error',
#        'log_test_error_before_ft', 'log_test_error',
#        'log_valid_error_before_ft', 'log_valid_error'],
#       dtype='object')

# %%
f = sns.lineplot(data=df, x='compression_ratio', y='test_acc', hue='compression')
f.get_figure().savefig('../../plots/gar_c10_dbs_after_ft.pdf')

# %%
f = sns.lineplot(data=df, x='compression_ratio', y='test_acc_before_ft', hue='compression')
f.get_figure().savefig('../../plots/gar_c10_dbs_before_ft.pdf')

# %%
'test_acc': 0.891
