# %%
import yaml
import json
from pathlib import Path
import pandas as pd
import torch

import seaborn as sns
sns.set_theme(style="darkgrid")

logdir = Path("/bigdata/f_mnist/logs/decomposed_adam")

# %%
import os
from datetime import datetime
from os.path import isdir

folders = os.listdir(logdir)
print(f"number of folders: {len(folders)}")
# Out:
# number of folders: 260

# %%
from datetime import datetime

dts = [datetime.fromtimestamp(int(x)) for x in folders]
print(max(dts))
print(min(dts))
# Out:
# 2491-04-14 20:23:52
# 2022-02-16 13:31:57

# %%
paths = []
for folder in folders:
    found_decomp = False
    found_results = False
    for subfolder in os.listdir(logdir / folder):
        if 'lr' in subfolder:
            # found_decomp = True
            # break
            if (logdir / folder / subfolder / "results.json").exists():
                paths.append( logdir / folder / subfolder )
    # if not found_decomp or not found_results:
    #     folders.remove(folder)
print(len(paths))
# Out:
# 260

# %%
# baseline

baseline_path = Path("/bigdata/f_mnist/logs/baselines/1644945876/rn18_18_dNone_256_adam_l0.001_g0.1_sTrue")
baseline_model = torch.load(baseline_path / "cnn_best.pth")

# %%
with open(baseline_path/'results.json') as json_file:
    baseline_result = json.load(json_file)

# %%
baseline_result
# Out:
# {'best_epoch': 171,
#  'best_train_acc': 0.9989454545454546,
#  'best_valid_acc': 0.9568,
#  'best_valid_loss': 0.001409929971396923,
#  'test_acc': 0.944,
#  'test_loss': 0.0016882505266927182,
#  'n_param': 11172810,
#  'model_name': 'rn18_18_dNone_256_adam_l0.001_g0.1_sTrue'}

# %%
# def paths_to_results(paths):
#     """Returns a pandas DataFrame with results"""
#     results = []
#     for path in paths:
#         with open(path/'results.json') as json_file:
#             result = json.load(json_file)
#         with open(path / 'results_feature_metrics.json') as json_file:
#             feature_result = json.load(json_file)
#         result.update(feature_result['mean'])
#         for k,v in result.items():
#             result[k] = v[0] if type(v) == list else v
#         results.append(result)
    
#     keys = set()
#     for result in results:
#         keys = keys.union( set(result.keys()) )
    
#     blank = {k:[] for k in keys}
    
#     df = pd.DataFrame(blank) #.append(results[1], ignore_index=True)

#     for result in results:
#         df = df.append(result, ignore_index=True)
        
#     df['compression'] = df['n_param_fact']/df['n_param'][0]
#     df.compression[0] = 1.0
    
    
#     return df

# %%
import torch
import tensorly as tl
tl.set_backend('pytorch')
from tddl.factorizations import number_layers
from tddl.factorizations import listify_numbered_layers

def relative_error(pre_weight, dec_weight):
    with torch.no_grad():
        return tl.norm(pre_weight-dec_weight)/tl.norm(pre_weight)

def process_factorized_network(model, fact_model, layer_nrs, first_layer_nr=0):

    pretrained_numbered_layers = number_layers(model)
    pretrained_layers = listify_numbered_layers(
        pretrained_numbered_layers, 
        layer_nrs=layer_nrs
    )

    decomposed_numbered_layers_resnet18 = number_layers(fact_model)
    decomposed_conv_layers_resnet18 = listify_numbered_layers(
        decomposed_numbered_layers_resnet18, 
        layer_nrs=layer_nrs
    )

    errors_conv_resnet18 = {
        'name': [],
        'nr': [],
        'error': [],
    }

    for pre, dec in zip(pretrained_layers, decomposed_conv_layers_resnet18):
        
        if pre[0] != dec[0]:
            print(f'breaking: {pre[0]} != {dec[0]}')
            break
        if pre[1] != dec[1]:
            print(f'breaking: {pre[1]} != {dec[1]}')
            break
        
        name = pre[0]
        print(name)
        nr = pre[1]
        print(nr)

        pre_weight = pre[2].weight
        dec_weight = dec[2].weight.to_tensor()

        error = relative_error(pre_weight, dec_weight)
        
        errors_conv_resnet18['name'].append(name)
        errors_conv_resnet18['nr'].append(nr)
        errors_conv_resnet18['error'].append(float(error))

    df_errors = pd.DataFrame(data=errors_conv_resnet18)
    if first_layer_nr is not None:
        df_errors.name.iloc[first_layer_nr] = 'in'
    df_errors.set_index('nr', inplace=True)
    grouped_errors = df_errors.groupby(by='name')
    grouped_errors['error'].plot(legend=True, style=".-", ylabel='Relative Error', xlabel='Layer Number')
# Out:
# /home/jetzeschuurman/gitProjects/phd/tltorch/tltorch/factorized_tensors/core.py:145: UserWarning: Creating a subclass of FactorizedTensor TensorizedTensor with no name.
#   warnings.warn(f'Creating a subclass of FactorizedTensor {cls.__name__} with no name.')

# %%
# calc approximation error
# store in approx_error.json, next to results.json
import yaml

for path in paths:
    print(path)
    timestamp = Path(path).parent
    config_path = logdir / timestamp / "config.yml"
    config_data = yaml.load(config_path.read_text(), Loader=yaml.Loader)
    layers = config_data['layers']

    fact_model = torch.load(path / 'model_after_fact.pth')

    pretrained_numbered_layers = number_layers(baseline_model)
    pretrained_layers = listify_numbered_layers(
        pretrained_numbered_layers,
        layer_nrs=layers,
    )

    decomposed_numbered_layers = number_layers(fact_model)
    decomposed_conv_layers = listify_numbered_layers(
        decomposed_numbered_layers,
        layer_nrs=layers,
    )

    with open(path / 'results.json') as json_file:
        result = json.load(json_file)

    with open(path / 'results_before_training.json') as json_file:
        result_before_training = json.load(json_file)

    errors_conv = {
            'name': [],
            'nr': [],
            'error': [],
            'layers': layers,
            'factorization': config_data['factorization'],
            'rank': config_data['rank'],
            'valid_acc': result['best_valid_acc'],
            'valid_acc_before_ft': result_before_training['valid_acc'],
            'n_param_fact': result['n_param_fact'],
            'test_acc': result['test_acc'],
            'lr': config_data['lr'],
            'optimizer': config_data['optimizer'],
        }

    with open(path / 'results_feature_metrics_train.json') as json_file:
        feature_result = json.load(json_file)
    train_features = feature_result['mean']
    errors_conv.update(train_features)

    # with open(path / 'results_feature_metrics_valid.json') as json_file:
    #     feature_result = json.load(json_file)
    # errors_conv.update()

    for pre, dec in zip(pretrained_layers, decomposed_conv_layers):
        
        if pre[0] != dec[0]:
            print(f'breaking: {pre[0]} != {dec[0]}')
            break
        if pre[1] != dec[1]:
            print(f'breaking: {pre[1]} != {dec[1]}')
            break
        
        name = pre[0]
        # print(name)
        nr = pre[1]
        # print(nr)

        pre_weight = pre[2].weight
        dec_weight = dec[2].weight.to_tensor()

        error = relative_error(pre_weight, dec_weight)
        # print(error)
        
        errors_conv['name'].append(name)
        errors_conv['nr'].append(nr)
        errors_conv['error'].append(float(error))

    errors_path = logdir / path / 'results_approximation_error.json'
    with open(errors_path, 'w') as f:
        json.dump(errors_conv, f)
# Out:
# /bigdata/f_mnist/logs/decomposed_adam/1645047993/rn18-lr-[38]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645048960/rn18-lr-[44]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645017615/rn18-lr-[28]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645030534/rn18-lr-[28]-tucker-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647072651/rn18-lr-[15]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645023670/rn18-lr-[15]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647136323/rn18-lr-[15]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647074315/rn18-lr-[19]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647139697/rn18-lr-[38]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645048639/rn18-lr-[41]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647091973/rn18-lr-[38]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647109710/rn18-lr-[38]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647076536/rn18-lr-[38]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647138013/rn18-lr-[19]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647078794/rn18-lr-[41]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645047643/rn18-lr-[38]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647099342/rn18-lr-[60]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645037585/rn18-lr-[28]-tucker-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647110275/rn18-lr-[41]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645031732/rn18-lr-[28]-tucker-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645044235/rn18-lr-[44]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645046343/rn18-lr-[15]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647123325/rn18-lr-[19]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645017628/rn18-lr-[38]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647132371/rn18-lr-[60]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645015336/rn18-lr-[28]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647121065/rn18-lr-[15]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645023094/rn18-lr-[15]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645034962/rn18-lr-[41]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647124455/rn18-lr-[38]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647082792/rn18-lr-[60]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645016476/rn18-lr-[28]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645039908/rn18-lr-[28]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647096497/rn18-lr-[44]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647123888/rn18-lr-[38]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645036966/rn18-lr-[28]-cp-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647085695/rn18-lr-[63]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647072096/rn18-lr-[15]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647090273/rn18-lr-[19]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647117072/rn18-lr-[63]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645030860/rn18-lr-[63]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647146395/rn18-lr-[60]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647090832/rn18-lr-[19]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647107991/rn18-lr-[38]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645042236/rn18-lr-[28]-tucker-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647145265/rn18-lr-[44]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647075977/rn18-lr-[38]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647114202/rn18-lr-[44]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645046992/rn18-lr-[19]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645032622/rn18-lr-[19]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647088596/rn18-lr-[15]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647128938/rn18-lr-[44]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647113081/rn18-lr-[44]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645027191/rn18-lr-[41]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645020586/rn18-lr-[60]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647106303/rn18-lr-[19]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645038755/rn18-lr-[28]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647120498/rn18-lr-[15]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645016441/rn18-lr-[19]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647087467/rn18-lr-[15]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647117649/rn18-lr-[63]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647149843/rn18-lr-[63]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647095374/rn18-lr-[41]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647138570/rn18-lr-[19]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647134643/rn18-lr-[63]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645045627/rn18-lr-[63]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647099917/rn18-lr-[60]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647111424/rn18-lr-[41]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645046670/rn18-lr-[15]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647075427/rn18-lr-[19]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647089158/rn18-lr-[15]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645024848/rn18-lr-[19]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645040403/rn18-lr-[15]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647140831/rn18-lr-[38]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645018197/rn18-lr-[28]-cp-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645032895/rn18-lr-[28]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647088032/rn18-lr-[15]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647128371/rn18-lr-[44]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647077665/rn18-lr-[38]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647126140/rn18-lr-[41]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647073771/rn18-lr-[19]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647115321/rn18-lr-[60]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645034403/rn18-lr-[38]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645042135/rn18-lr-[38]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645028940/rn18-lr-[60]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647085125/rn18-lr-[63]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645049631/rn18-lr-[60]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647101094/rn18-lr-[63]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645024229/rn18-lr-[19]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647079363/rn18-lr-[41]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645042748/rn18-lr-[38]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647098200/rn18-lr-[44]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647122759/rn18-lr-[19]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647125581/rn18-lr-[38]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647136892/rn18-lr-[15]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647132932/rn18-lr-[63]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645035810/rn18-lr-[28]-cp-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645026609/rn18-lr-[41]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645014717/rn18-lr-[15]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645027613/rn18-lr-[28]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647135767/rn18-lr-[15]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645018215/rn18-lr-[41]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647079932/rn18-lr-[41]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645024690/rn18-lr-[28]-tucker-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645018794_2/rn18-lr-[41]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647126710/rn18-lr-[41]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645035211/rn18-lr-[28]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645036127/rn18-lr-[44]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647143602/rn18-lr-[41]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647092546/rn18-lr-[38]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645048317/rn18-lr-[41]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647073215/rn18-lr-[15]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645025274/rn18-lr-[28]-cp-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645038162/rn18-lr-[28]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645022926/rn18-lr-[28]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647107436/rn18-lr-[19]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647146966/rn18-lr-[60]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645044909/rn18-lr-[60]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647094261/rn18-lr-[41]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647091405/rn18-lr-[19]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645027034/rn18-lr-[28]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645029942/rn18-lr-[28]-cp-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647098767/rn18-lr-[60]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645036387/rn18-lr-[28]-tucker-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647082228/rn18-lr-[44]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645039330/rn18-lr-[28]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645045291/rn18-lr-[60]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647104022/rn18-lr-[15]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645020577/rn18-lr-[28]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647140267/rn18-lr-[38]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645034628/rn18-lr-[28]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647149279/rn18-lr-[63]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647112523/rn18-lr-[44]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647081082/rn18-lr-[44]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647111971/rn18-lr-[41]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645036742/rn18-lr-[44]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645022346/rn18-lr-[28]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645022507/rn18-lr-[63]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647147535/rn18-lr-[60]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645019423_2/rn18-lr-[44]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647127263/rn18-lr-[41]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645020011/rn18-lr-[28]-tucker-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647109124/rn18-lr-[38]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647084546/rn18-lr-[60]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647129496/rn18-lr-[44]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645035568/rn18-lr-[41]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647080504/rn18-lr-[44]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645050346/rn18-lr-[63]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647143062/rn18-lr-[41]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647118811/rn18-lr-[63]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647135214/rn18-lr-[15]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647125010/rn18-lr-[38]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645044585/rn18-lr-[44]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645034052/rn18-lr-[28]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647104585/rn18-lr-[15]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647093703/rn18-lr-[38]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647081645/rn18-lr-[44]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647142521/rn18-lr-[41]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647086877/rn18-lr-[63]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645015897/rn18-lr-[28]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645039827/rn18-lr-[15]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647101679/rn18-lr-[63]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645043403/rn18-lr-[28]-tucker-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645041065/rn18-lr-[28]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647121634/rn18-lr-[19]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647113632/rn18-lr-[44]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645015850/rn18-lr-[19]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647102862/rn18-lr-[63]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647115891/rn18-lr-[60]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647083372/rn18-lr-[60]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647130068/rn18-lr-[44]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645026439/rn18-lr-[28]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647127819/rn18-lr-[41]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645049308/rn18-lr-[44]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647095936/rn18-lr-[41]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645031125/rn18-lr-[28]-cp-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647139137/rn18-lr-[19]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645043876/rn18-lr-[41]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645024076/rn18-lr-[28]-cp-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645014757/rn18-lr-[28]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645041644/rn18-lr-[28]-cp-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645038582/rn18-lr-[63]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645017017/rn18-lr-[38]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647086277/rn18-lr-[63]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647119380/rn18-lr-[15]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645040475/rn18-lr-[28]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647083943/rn18-lr-[60]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647094824/rn18-lr-[41]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647144704/rn18-lr-[44]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647133492/rn18-lr-[63]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647102262/rn18-lr-[63]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647100507/rn18-lr-[60]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647093117/rn18-lr-[38]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645020018/rn18-lr-[44]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647118213/rn18-lr-[63]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645032320/rn18-lr-[28]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645042810/rn18-lr-[28]-cp-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647105169/rn18-lr-[15]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647148139/rn18-lr-[60]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645031452/rn18-lr-[15]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645021743/rn18-lr-[28]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647150433/rn18-lr-[63]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647119942/rn18-lr-[15]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647106868/rn18-lr-[19]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647097622/rn18-lr-[44]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647122197/rn18-lr-[19]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645019423/rn18-lr-[28]-cp-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645023509/rn18-lr-[28]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647071530/rn18-lr-[15]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645040969/rn18-lr-[19]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647074866/rn18-lr-[19]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647145844/rn18-lr-[44]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647148709/rn18-lr-[63]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645033790/rn18-lr-[38]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645021836/rn18-lr-[63]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647116492/rn18-lr-[60]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647097062/rn18-lr-[44]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647108563/rn18-lr-[38]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647089719/rn18-lr-[19]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647130622/rn18-lr-[60]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645028188/rn18-lr-[28]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645030194/rn18-lr-[63]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645039239/rn18-lr-[63]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645017035/rn18-lr-[28]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647141978/rn18-lr-[41]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645018794/rn18-lr-[28]-tucker-0.75-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647110850/rn18-lr-[41]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645050011/rn18-lr-[60]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645029602/rn18-lr-[60]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645041556/rn18-lr-[19]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645021154/rn18-lr-[28]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645033211/rn18-lr-[19]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647114755/rn18-lr-[60]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645021243/rn18-lr-[60]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645025415/rn18-lr-[38]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645025871/rn18-lr-[28]-tucker-0.9-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647077095/rn18-lr-[38]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645032055/rn18-lr-[15]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647141420/rn18-lr-[38]-tucker-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645047321/rn18-lr-[19]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647103450/rn18-lr-[15]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645046008/rn18-lr-[63]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645037307/rn18-lr-[60]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647078230/rn18-lr-[41]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645029360/rn18-lr-[28]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645026029/rn18-lr-[38]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645043307/rn18-lr-[41]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647131772/rn18-lr-[60]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647105733/rn18-lr-[19]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645050728/rn18-lr-[63]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645037977/rn18-lr-[60]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645028767/rn18-lr-[28]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647131193/rn18-lr-[60]-tucker-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645033490/rn18-lr-[28]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645028367/rn18-lr-[44]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645027758/rn18-lr-[44]-cp-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647137449/rn18-lr-[19]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647144147/rn18-lr-[44]-cp-0.1-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1645015275/rn18-lr-[15]-tucker-0.5-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue
# /bigdata/f_mnist/logs/decomposed_adam/1647134051/rn18-lr-[63]-cp-0.25-dTrue-iNone_bn_256_sgd_l1e-05_g0.0_sTrue

# %%
results = []
for path in paths:
    with open(path / 'results_approximation_error.json') as json_file:
        result = json.load(json_file)
    # print(result)
    for k,v in result.items():
        result[k] = v[0] if type(v) == list else v
    results.append(result)

# %%
df = pd.DataFrame(results)
print(len(df))
df.head()
# Out:
# 260
#     name  nr     error  layers factorization  rank  valid_acc  \
# 0  conv2  38  0.417412      38        tucker   0.5     0.9566
# 1  conv1  44  0.320085      44            cp   0.5     0.9566
# 2  conv1  28  0.538858      28        tucker  0.50     0.9528
# 3  conv1  28  0.392214      28        tucker  0.75     0.9550
# 4  conv2  15  0.548970      15            cp  0.25     0.9538
#
#    valid_acc_before_ft  n_param_fact  test_acc       lr optimizer   norm_diff  \
# 0               0.9560      10878589    0.9445  0.00001      adam   73.751099
# 1               0.9566      10878297    0.9448  0.00001      adam   69.962518
# 2               0.9512      11098445    0.9451  0.00001      adam  118.639486
# 3               0.9534      11136896    0.9453  0.00001      adam   82.524876
# 4               0.9526      11145261    0.9443  0.00001      adam   84.728561
#
#        norm_b      n_b  relative_norm  scaled_norm
# 0  441.326247   4096.0       0.167286     0.018006
# 1  861.984651   4096.0       0.081277     0.017081
# 2  420.734193   6272.0       0.282127     0.018916
# 3  420.734193   6272.0       0.196265     0.013158
# 4  366.026601  12544.0       0.231576     0.006755

# %%
df['rank'] = df['rank'].astype(float, copy=False)
# df['rank'].apply(float)
df['rank'].unique()
df['fact_rank'] = df['factorization'] + '-' + df['rank'].apply(str)
df['fact_layers'] = df['factorization'] + '-' + df['layers'].apply(str)
df['layers_fact'] = df['layers'].apply(str) + '-' + df['factorization'] 
df.head()
# Out:
#     name  nr     error  layers factorization  rank  valid_acc  \
# 0  conv2  38  0.417412      38        tucker  0.50     0.9566
# 1  conv1  44  0.320085      44            cp  0.50     0.9566
# 2  conv1  28  0.538858      28        tucker  0.50     0.9528
# 3  conv1  28  0.392214      28        tucker  0.75     0.9550
# 4  conv2  15  0.548970      15            cp  0.25     0.9538
#
#    valid_acc_before_ft  n_param_fact  test_acc       lr optimizer   norm_diff  \
# 0               0.9560      10878589    0.9445  0.00001      adam   73.751099
# 1               0.9566      10878297    0.9448  0.00001      adam   69.962518
# 2               0.9512      11098445    0.9451  0.00001      adam  118.639486
# 3               0.9534      11136896    0.9453  0.00001      adam   82.524876
# 4               0.9526      11145261    0.9443  0.00001      adam   84.728561
#
#        norm_b      n_b  relative_norm  scaled_norm    fact_rank fact_layers  \
# 0  441.326247   4096.0       0.167286     0.018006   tucker-0.5   tucker-38
# 1  861.984651   4096.0       0.081277     0.017081       cp-0.5       cp-44
# 2  420.734193   6272.0       0.282127     0.018916   tucker-0.5   tucker-28
# 3  420.734193   6272.0       0.196265     0.013158  tucker-0.75   tucker-28
# 4  366.026601  12544.0       0.231576     0.006755      cp-0.25       cp-15
#
#   layers_fact
# 0   38-tucker
# 1       44-cp
# 2   28-tucker
# 3   28-tucker
# 4       15-cp

# %%
df = df.astype({
    'layers':"category",
    'fact_layers':"category",
    'layers_fact':"category",
})

# %% [markdown]
# ## Approximation error on the weights

# %%
df_rank = df.set_index('rank', inplace=False)

# %%
grouped_df = df_rank.groupby('factorization')
ax = grouped_df['error'].plot(legend=True, style=".", ylabel='relative approximation error on weights', xlabel='relative rank')

# %%
# df = pd.DataFrame(results)
# df['rank'] = df['rank'].astype(float, copy=False)
# Plot the responses for different events and regions
ax = sns.lineplot(x="rank", y="error",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)

# %%
ax = sns.pointplot(x="rank", y="error",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax = ax.set(xlabel='relative rank', ylabel='relative approximation error on weights')

# %%
ax = sns.pointplot(x="rank", y="valid_acc_before_ft",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='relative rank', ylabel='validation accuracy before finetuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="rank", y="valid_acc_before_ft",
    hue="factorization",
    # style="factorization",
    data=df,
    # palette=['orange', 'black', 'red', 'green', 'blue', 'yellow'], #['orange','b']
)
ax = ax.axhline(baseline_result['best_valid_acc'], color='r')

# %%
ax = sns.scatterplot(x="rank", y="valid_acc",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax = ax.axhline(baseline_result['best_valid_acc'], color='r')

# %%
ax = sns.pointplot(x="rank", y="valid_acc",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(xlabel='relative rank', ylabel='validation accuracy after finetuning')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.pointplot(x="rank", y="test_acc",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax.axhline(baseline_result['test_acc'], color='r')
ax.set(xlabel='relative rank', ylabel='test accuracy after finetuning')
# ax.set(ylim=(0.865, 0.925))
# Out:
# [Text(0.5, 0, 'relative rank'), Text(0, 0.5, 'test accuracy after finetuning')]

# %%
ax = sns.scatterplot(x="rank", y="test_acc",
    hue="factorization",
    # style="rank",
    data=df,
    palette=['orange', 'b'],
)
ax = ax.axhline(baseline_result['test_acc'], color='r')

# %%
# df = pd.DataFrame(results)
# df.set_index('error', inplace=True)
# grouped_df = df.groupby('factorization')
# grouped_df['rank'].plot(legend=True, style=".-", ylabel='relative rank', xlabel='relative approximation error')

# %%
# df = pd.DataFrame(results)
# df.set_index('error', inplace=True)
# grouped_df = df.groupby('factorization')
# grouped_df['valid_acc'].plot(legend=True, style=".", ylabel='validation accuracy after fine-tuning', xlabel='relative approximation error')

# %%
ax = sns.scatterplot(
    x="error", y="valid_acc_before_ft", 
    hue="factorization", 
    # style="factorization",
    data=df,
    palette=['orange', 'b'], 
)
ax.set(xlabel='relative approximation error on weights', ylabel='validation accuracy before fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="error", y="valid_acc",
    hue="factorization", 
    data=df,
    palette=['orange', 'b'], 
)
ax.set(xlabel='relative approximation error on weights', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="error", y="test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='relative approximation error on weights', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
g = sns.lmplot(x="error", y="valid_acc",
    hue="factorization", data=df,
    # y_jitter=.02, 
    # logistic=True, 
    # style="rank",
    truncate=False, palette=['orange', 'b'], 
)
g = g.set(xlabel='relative approximation error', ylabel='validation accuracy after fine-tuning')

# %%
df['fact_rank'] = df['factorization'] + '-' + df['rank'].apply(str)
df.head()
# Out:
#     name  nr     error layers factorization  rank  valid_acc  \
# 0  conv2  38  0.417412     38        tucker  0.50     0.9566
# 1  conv1  44  0.320085     44            cp  0.50     0.9566
# 2  conv1  28  0.538858     28        tucker  0.50     0.9528
# 3  conv1  28  0.392214     28        tucker  0.75     0.9550
# 4  conv2  15  0.548970     15            cp  0.25     0.9538
#
#    valid_acc_before_ft  n_param_fact  test_acc       lr optimizer   norm_diff  \
# 0               0.9560      10878589    0.9445  0.00001      adam   73.751099
# 1               0.9566      10878297    0.9448  0.00001      adam   69.962518
# 2               0.9512      11098445    0.9451  0.00001      adam  118.639486
# 3               0.9534      11136896    0.9453  0.00001      adam   82.524876
# 4               0.9526      11145261    0.9443  0.00001      adam   84.728561
#
#        norm_b      n_b  relative_norm  scaled_norm    fact_rank fact_layers  \
# 0  441.326247   4096.0       0.167286     0.018006   tucker-0.5   tucker-38
# 1  861.984651   4096.0       0.081277     0.017081       cp-0.5       cp-44
# 2  420.734193   6272.0       0.282127     0.018916   tucker-0.5   tucker-28
# 3  420.734193   6272.0       0.196265     0.013158  tucker-0.75   tucker-28
# 4  366.026601  12544.0       0.231576     0.006755      cp-0.25       cp-15
#
#   layers_fact
# 0   38-tucker
# 1       44-cp
# 2   28-tucker
# 3   28-tucker
# 4       15-cp

# %%
# g = sns.lmplot(x="error", y="test_acc", 
#    hue="fact_rank", 
#    data=df,
#    truncate=False, 
#    # palette=['orange','b'],
# )
# g.set(xlabel='relative approximation error', ylabel='test accuracy after fine-tuning')
# g.set(ylim=(0.935, 0.945))

# %%
ax = sns.lmplot(x="error", y="test_acc", 
   hue="factorization", 
   data=df,
   # logistic=True,
   truncate=False, 
   palette=['orange','b'],
)
ax.set(xlabel='relative approximation error', ylabel='test accuracy after fine-tuning')

# %%
# df = pd.DataFrame(results)
# df.set_index('error', inplace=True)
# grouped_df = df.groupby('factorization')
# grouped_df['valid_acc_before_ft'].plot(legend=True, style=".", ylabel='validation accuracy before fine-tuning', xlabel='relative approximation error')

# %%
g = sns.lmplot(x="error", y="valid_acc_before_ft", hue="factorization", data=df,
            #    y_jitter=.02, 
               # logistic=True, 
               truncate=False, 
               palette=['orange', 'b'], 
               )
g.set(xlabel='relative approximation error', ylabel='validation accuracy before fine-tuning')

# %%
df_layers = pd.DataFrame(results)
df_layers['rank'] = df_layers['rank'].astype(float, copy=False)
df_layers = df_layers.loc[df_layers['rank'] == 0.5]
df_layers
# Out:
#       name  nr     error  layers factorization  rank  valid_acc  \
# 0    conv2  38  0.417412      38        tucker   0.5     0.9566
# 1    conv1  44  0.320085      44            cp   0.5     0.9566
# 2    conv1  28  0.538858      28        tucker   0.5     0.9528
# 5    conv2  15  0.508273      15        tucker   0.5     0.9538
# 9        0  41  0.661809      41        tucker   0.5     0.9548
# ..     ...  ..       ...     ...           ...   ...        ...
# 250  conv1  60  0.248301      60        tucker   0.5     0.9564
# 251  conv1  28  0.408988      28            cp   0.5     0.9564
# 254  conv1  44  0.405947      44        tucker   0.5     0.9564
# 255  conv1  44  0.318756      44            cp   0.5     0.9566
# 258  conv2  15  0.508273      15        tucker   0.5     0.9538
#
#      valid_acc_before_ft  n_param_fact  test_acc       lr optimizer  \
# 0                 0.9560      10878589    0.9445  0.00001      adam
# 1                 0.9566      10878297    0.9448  0.00001      adam
# 2                 0.9512      11098445    0.9451  0.00001      adam
# 5                 0.9532      11154645    0.9453  0.00001      adam
# 9                 0.9548      11156556    0.9456  0.00001      adam
# ..                   ...           ...       ...      ...       ...
# 250               0.9568       9995872    0.9449  0.00001      adam
# 251               0.9552      11099257    0.9443  0.00001      adam
# 254               0.9564      10878589    0.9441  0.00001      adam
# 255               0.9564      10878297    0.9448  0.00001      adam
# 258               0.9532      11154645    0.9452  0.00001      adam
#
#       norm_diff       norm_b      n_b  relative_norm  scaled_norm
# 0     73.751099   441.326247   4096.0       0.167286     0.018006
# 1     69.962518   861.984651   4096.0       0.081277     0.017081
# 2    118.639486   420.734193   6272.0       0.282127     0.018916
# 5     99.056845   366.026601  12544.0       0.270698     0.007897
# 9     59.461849   134.730559   4096.0       0.441798     0.014517
# ..          ...          ...      ...            ...          ...
# 250   36.333462  1497.369205   2048.0       0.024424     0.017741
# 251   73.881649   420.734193   6272.0       0.175713     0.011780
# 254  114.326228   861.984651   4096.0       0.132776     0.027912
# 255   70.036598   861.984651   4096.0       0.081364     0.017099
# 258   99.056853   366.026601  12544.0       0.270699     0.007897
#
# [80 rows x 17 columns]

# %%
df_layers_idx = df_layers.set_index('layers', inplace=False)
grouped_df_layers = df_layers_idx.groupby('factorization')
ax = grouped_df_layers['error'].plot(legend=True, style=".", ylabel='relative approximation error')

# %%
# df_layers = pd.DataFrame(results_layers)
# df_layers.set_index('layers', inplace=True)
# grouped_df = df_layers.groupby('factorization')
# grouped_df['error'].plot(legend=True, style=".-", ylabel='relative approximation error')

# ax = grouped_df_layers['valid_acc'].plot(legend=True, style=".", ylabel='validation accuracy after fine-tuning', xlabel='relative approximation error')

# %%
# df_layers = pd.DataFrame(results_layers)
# df_layers.set_index('error', inplace=True)
# grouped_df = df_layers.groupby('factorization')
# grouped_df['valid_acc_before_ft'].plot(legend=True, style=".", ylabel='validation accuracy before fine-tuning', xlabel='relative approximation error')

# %%
# df = pd.DataFrame(results)
# df['rank'] = df['rank'].astype(float, copy=False)

# Plot the responses for different events and regions
ax = sns.lineplot(x="layers", y="error",
             hue="factorization", 
            #  style="rank",
             data=df_layers,
             palette=['orange', 'b'],
             )

# %%
ax = sns.pointplot(x="layers", y="error",
             hue="factorization", 
            #  style="rank",
             data=df_layers,
             palette=['orange', 'b'],
             dodge=True
             )

# %%
g = sns.lmplot(x="error", y="valid_acc_before_ft", hue="factorization", data=df_layers,
            #    y_jitter=.02, 
               # logistic=True, 
               truncate=False, 
               palette=['orange', 'b'], 
               )
g.set(xlabel='relative approximation error', ylabel='validation accuracy before fine-tuning')

# %%
g = sns.lmplot(x="error", y="valid_acc", hue="factorization", data=df_layers,
            #    y_jitter=.02, 
               # logistic=True, 
               truncate=False, 
               palette=['orange', 'b'], 
               )
g.set(xlabel='relative approximation error', ylabel='validation accuracy after fine-tuning')

# %%
g = sns.lmplot(x="error", y="test_acc", hue="factorization", data=df_layers,
            #    y_jitter=.02, 
               # logistic=True, 
               truncate=False, 
               palette=['orange', 'b'], 
               )
g.set(xlabel='relative approximation error', ylabel='test accuracy after fine-tuning')

# %%
ax = sns.scatterplot(x="layers", y="valid_acc_before_ft",
    hue="factorization", 
    # style="rank",
    data=df_layers,
    palette=['orange', 'b'],
    # dodge=True,
    )
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(xlabel='layer number', ylabel='validation accuracy before fine-tuning')
# ax.set(ylim=(0.908, 0.9220))
# Out:
# [Text(0.5, 0, 'layer number'),
#  Text(0, 0.5, 'validation accuracy before fine-tuning')]

# %%
ax = sns.pointplot(x="layers", y="valid_acc_before_ft",
    hue="factorization", 
    # style="rank",
    data=df_layers,
    palette=['orange', 'b'],
    dodge=True,
    )
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(xlabel='layer number', ylabel='validation accuracy before fine-tuning')
ax.set(ylim=(0.908, 0.9220))
# Out:
# [(0.908, 0.922)]

# %%
ax = sns.pointplot(x="layers", y="valid_acc",
    hue="factorization", 
    # style="rank",
    data=df_layers,
    palette=['orange', 'b'],
    dodge=True,
    )
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(xlabel='layer number', ylabel='validation accuracy after fine-tuning')
ax.set(ylim=(0.908, 0.9220))
# Out:
# [(0.908, 0.922)]

# %%
ax = sns.pointplot(x="layers", y="test_acc",
             hue="factorization", 
            #  style="rank",
             data=df_layers,
             palette=['orange', 'b'],
             dodge=True)
ax.axhline(baseline_result['test_acc'], color='r')
ax.set(xlabel='layer number', ylabel='test accuracy after fine-tuning')
# Out:
# [Text(0.5, 0, 'layer number'), Text(0, 0.5, 'test accuracy after fine-tuning')]

# %%
df.factorization.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# Name: factorization, Length: 260, dtype: bool

# %%
df[df.error.isnull()]
# Out:
# Empty DataFrame
# Columns: [name, nr, error, layers, factorization, rank, valid_acc, valid_acc_before_ft, n_param_fact, test_acc, lr, optimizer, norm_diff, norm_b, n_b, relative_norm, scaled_norm, fact_rank, fact_layers, layers_fact]
# Index: []

# %%
df_layer_rank = df.groupby(['factorization','layers','rank'])
df_std = df_layer_rank[['valid_acc','test_acc']].std()

print(df_std.to_latex())

# df.to_json("/home/jetzeschuurman/gitProjects/phd/tddl/artifacts/f_mnist/std_adam.json")
# Out:
# \begin{tabular}{lllrr}
# \toprule
#        &    &      &  valid\_acc &  test\_acc \\
# factorization & layers & rank &            &           \\
# \midrule
# cp & 15 & 0.10 &   0.000576 &  0.000731 \\
#        &    & 0.25 &   0.000856 &  0.000532 \\
#        &    & 0.50 &   0.000522 &  0.000614 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 19 & 0.10 &   0.000841 &  0.001007 \\
#        &    & 0.25 &   0.001000 &  0.000466 \\
#        &    & 0.50 &   0.000460 &  0.000192 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 28 & 0.10 &   0.001354 &  0.000777 \\
#        &    & 0.25 &   0.000329 &  0.000844 \\
#        &    & 0.50 &   0.001223 &  0.000650 \\
#        &    & 0.75 &   0.000548 &  0.000089 \\
#        &    & 0.90 &   0.000693 &  0.000835 \\
#        & 38 & 0.10 &   0.000537 &  0.000568 \\
#        &    & 0.25 &   0.000438 &  0.000428 \\
#        &    & 0.50 &   0.000456 &  0.000311 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 41 & 0.10 &   0.000358 &  0.000327 \\
#        &    & 0.25 &   0.000385 &  0.000391 \\
#        &    & 0.50 &   0.000469 &  0.000084 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 44 & 0.10 &   0.000477 &  0.000743 \\
#        &    & 0.25 &   0.000316 &  0.000230 \\
#        &    & 0.50 &   0.000100 &  0.000141 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 60 & 0.10 &   0.000477 &  0.000515 \\
#        &    & 0.25 &   0.000329 &  0.000336 \\
#        &    & 0.50 &   0.000167 &  0.000148 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 63 & 0.10 &   0.000385 &  0.000835 \\
#        &    & 0.25 &   0.000200 &  0.000235 \\
#        &    & 0.50 &   0.000141 &  0.000321 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
# tucker & 15 & 0.10 &   0.000540 &  0.000689 \\
#        &    & 0.25 &   0.000228 &  0.000235 \\
#        &    & 0.50 &   0.000456 &  0.000394 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 19 & 0.10 &   0.000167 &  0.000224 \\
#        &    & 0.25 &   0.000283 &  0.000344 \\
#        &    & 0.50 &   0.000303 &  0.000635 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 28 & 0.10 &   0.000518 &  0.000415 \\
#        &    & 0.25 &   0.000548 &  0.000305 \\
#        &    & 0.50 &   0.000167 &  0.000390 \\
#        &    & 0.75 &   0.000179 &  0.000305 \\
#        &    & 0.90 &   0.000245 &  0.000114 \\
#        & 38 & 0.10 &   0.000297 &  0.000500 \\
#        &    & 0.25 &   0.000268 &  0.000541 \\
#        &    & 0.50 &   0.000510 &  0.000268 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 41 & 0.10 &   0.000583 &  0.000277 \\
#        &    & 0.25 &   0.000385 &  0.000158 \\
#        &    & 0.50 &   0.000434 &  0.000346 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 44 & 0.10 &   0.000303 &  0.000365 \\
#        &    & 0.25 &   0.000268 &  0.000456 \\
#        &    & 0.50 &   0.000335 &  0.000308 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 60 & 0.10 &   0.000335 &  0.000356 \\
#        &    & 0.25 &   0.000329 &  0.000358 \\
#        &    & 0.50 &   0.000228 &  0.000573 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
#        & 63 & 0.10 &   0.000268 &  0.000308 \\
#        &    & 0.25 &   0.000228 &  0.000445 \\
#        &    & 0.50 &   0.000261 &  0.000482 \\
#        &    & 0.75 &        NaN &       NaN \\
#        &    & 0.90 &        NaN &       NaN \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Analysis on the features space

# %% [markdown]
# ### Relative Norm

# %%
ax = sns.scatterplot(
    x="relative_norm", y="valid_acc_before_ft", 
     hue="factorization", 
    # style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(
    xlabel='relative approximation error on training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="relative_norm", y="valid_acc",
     hue="factorization", 
    # style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='relative approximation error on train features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="relative_norm", y="test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='relative approximation error on train features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %% [markdown]
# ### Scaled Norm

# %%
ax = sns.scatterplot(
    x="scaled_norm", y="valid_acc_before_ft", 
    hue="factorization", 
    data=df,
    palette=['orange', 'b'], 
)
ax.set(
    xlabel='scaled norm of training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="scaled_norm", y="valid_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'], 
)
ax.set(xlabel='scaled norm of train features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="scaled_norm", y="test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='scaled norm of train features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %% [markdown]
# ### Norm of Difference

# %%
ax = sns.scatterplot(
    x="norm_diff", y="valid_acc_before_ft", 
    hue="factorization", 
    data=df,
    palette=['orange', 'b'], 
)
ax.set(
    xlabel='norm of difference on training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="norm_diff", y="valid_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'], 
)
ax.set(xlabel='norm of difference on training features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="norm_diff", y="test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='norm of difference on training features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
import numpy as np
df['log_norm_diff'] = np.log(df.norm_diff)

# %%
ax = sns.scatterplot(x="log_norm_diff", y="test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='log norm of difference on training features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
df['log_test_acc'] = np.log(df.test_acc)

# %%
ax = sns.scatterplot(x="log_norm_diff", y="log_test_acc",
    hue="factorization", data=df,
    palette=['orange', 'b'],
)
ax.set(xlabel='log norm of difference on training features', ylabel='log test accuracy after fine-tuning')
ax.axhline(np.log(baseline_result['test_acc']), color='g')
# ax.set(ylim=(0.865, 0.925))

# %% [markdown]
# # Per Layer

# %%
ax = sns.scatterplot(x="error", y="valid_acc_before_ft",
    hue="layers",
    style="factorization",
    data=df,
    # palette=['orange', 'black', 'red', 'green', 'blue', 'yellow'], #['orange','b']
)
ax.set(xlabel='relative approximation error on weights', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
# Out:
# [(0.865, 0.925)]

# %%
ax = sns.scatterplot(x="error", y="valid_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
    
)
ax.set(xlabel='relative approximation error on weights', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="error", y="test_acc",
    hue="layers",
    style="factorization", 
    data=df,
    # palette=['orange', 'b'],
)
ax.set(xlabel='relative approximation error on weights', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## Feature Space

# %% [markdown]
# ### Relative Norm

# %%
ax = sns.scatterplot(
    x="relative_norm", y="valid_acc_before_ft", 
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(
    xlabel='relative approximation error on training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="relative_norm", y="valid_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='relative approximation error on train features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="relative_norm", y="test_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='relative approximation error on train features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ### Scaled Norm

# %%
ax = sns.scatterplot(
    x="scaled_norm", y="valid_acc_before_ft", 
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(
    xlabel='scaled norm of training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="scaled_norm", y="valid_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='scaled norm of train features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="scaled_norm", y="test_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='scaled norm of train features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ### Norm of Difference

# %%
ax = sns.scatterplot(
    x="norm_diff", y="valid_acc_before_ft", 
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(
    xlabel='norm of difference on training features', 
    ylabel='validation accuracy before fine-tuning'
)
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="norm_diff", y="valid_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='norm of difference on training features', ylabel='validation accuracy after fine-tuning')
ax.axhline(baseline_result['best_valid_acc'], color='r')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = sns.scatterplot(x="norm_diff", y="test_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='norm of difference on training features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
# ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
import numpy as np
df['log_norm_diff'] = np.log(df.norm_diff)

# %%
ax = sns.scatterplot(x="log_norm_diff", y="test_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='log norm of difference on training features', ylabel='test accuracy after fine-tuning')
ax.axhline(baseline_result['test_acc'], color='g')
ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
df['log_test_acc'] = np.log(df.test_acc)

# %%
ax = sns.scatterplot(x="log_norm_diff", y="log_test_acc",
    hue="layers", 
    style="factorization",
    data=df,
    # palette=['orange', 'b'], 
)
ax.set(xlabel='log norm of difference on training features', ylabel='log test accuracy after fine-tuning')
ax.axhline(np.log(baseline_result['test_acc']), color='g')
# ax.set(ylim=(0.865, 0.925))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
g = sns.FacetGrid(df, col="layers", hue="factorization")
g.map(sns.scatterplot, "relative_norm", "valid_acc_before_ft", alpha=.7)
g.add_legend()

# %%
g = sns.FacetGrid(df, col="layers", hue="factorization")
g.map(sns.scatterplot, "relative_norm", "valid_acc", alpha=.7)
g.add_legend()

# %%
g = sns.FacetGrid(df, col="layers", hue="factorization")
g.map(sns.scatterplot, "relative_norm", "test_acc", alpha=.7)
g.add_legend()
# g.axhline(np.log(baseline_result['test_acc']), color='g')

# %%
replacements = {
    'valid_acc_before_ft': "Validation accuracy before fine-tuning", 
    'valid_acc': "Validation accuracy after fine-tuning",
    'test_acc': "Test accuracy after fine-tuning", 
    'error': 'Relative norm on weights',
    'relative_norm': 'Relative norm on training features',
    'scaled_norm': 'Scaled norm on training features',
    'norm_diff': 'Norm of the difference between training features',
    'log_norm_diff': 'Log norm of the difference between training features',
}

# %%
g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"norm_diff"],
    hue="layers",
    height=4,
    # style="factorization",
) #, height=4)
g.map(sns.scatterplot) # color=".3")
# g.set(ylim=(0.86,0.925))
# g.set(ylim=(-1, 11), yticks=[0, 5, 10])
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(4):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

# %%
from matplotlib import pyplot as plt 

g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"norm_diff"],
    height=4,
)
g.map(lambda x, y, **kwargs: sns.scatterplot(x=x,y=y,hue=df.layers,style=df.factorization,legend='auto')) # color=".3")
# g.set(ylim=(0.86,0.925))
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(4):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])
plt.legend(
    bbox_to_anchor=(1.05, 1,1,1),
    loc='upper left', borderaxespad=0.
    # loc='right',
    # bbox_to_anchor=(1.1, 0.5, 0, 0),
)
# g.fig.get_children()[-1].set_bbox_to_anchor((1.1, 0.5, 0, 0))
# Out:
# /home/jetzeschuurman/gitProjects/phd/tddl/venv/lib/python3.8/site-packages/seaborn/axisgrid.py:156: UserWarning: The handle <matplotlib.patches.Patch object at 0x7fee94c9f070> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %%
ylim = (0.935,0.958)

# %%
from matplotlib import pyplot as plt 

g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"log_norm_diff"],
    height=4,
)
g.map(lambda x, y, **kwargs: sns.scatterplot(x=x,y=y,hue=df.layers,style=df.factorization,legend='auto')) # color=".3")
g.set(ylim=ylim)
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(4):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])
plt.legend(
    bbox_to_anchor=(1.05, 1,1,1),
    loc='upper left', borderaxespad=0.
    # loc='right',
    # bbox_to_anchor=(1.1, 0.5, 0, 0),
)
# g.fig.get_children()[-1].set_bbox_to_anchor((1.1, 0.5, 0, 0))

g.savefig("../../plots/fmnist/rn18/rn18_fm_scatter_errors_performances_layers_factorizations")
# Out:
# /home/jetzeschuurman/gitProjects/phd/tddl/venv/lib/python3.8/site-packages/seaborn/axisgrid.py:156: UserWarning: The handle <matplotlib.patches.Patch object at 0x7fee69987610> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %%
# !pwd
# Out:
# /home/jetzeschuurman/gitProjects/phd/tddl/notebooks/results

# %%
g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"norm_diff"],
    hue="factorization",
    height=4,
    # style="factorization",
) #, height=4)
g.map(sns.scatterplot) # color=".3")
g.set(ylim=ylim)
# g.set(ylim=(-1, 11), yticks=[0, 5, 10])
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(4):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

# %%
g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"norm_diff"],
    hue="fact_layers",
    height=4,
    hue_order=[
        'cp-15','tucker-15','cp-19','tucker-19','cp-28','tucker-28','cp-38','tucker-38',
        'cp-41','tucker-41','cp-44','tucker-44','cp-60','tucker-60','cp-63','tucker-63',
    ]
    # palette=['b','orange']
    # style="factorization",
) #, height=4)
g.map(sns.scatterplot) # color=".3")
g.set(ylim=(0.86,0.925))
# g.set(ylim=(-1, 11), yticks=[0, 5, 10])
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(4):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

# %%
df
# Out:
#       name  nr     error layers factorization  rank  valid_acc  \
# 0    conv2  38  0.417412     38        tucker  0.50     0.9566
# 1    conv1  44  0.320085     44            cp  0.50     0.9566
# 2    conv1  28  0.538858     28        tucker  0.50     0.9528
# 3    conv1  28  0.392214     28        tucker  0.75     0.9550
# 4    conv2  15  0.548970     15            cp  0.25     0.9538
# ..     ...  ..       ...    ...           ...   ...        ...
# 255  conv1  44  0.318756     44            cp  0.50     0.9566
# 256  conv1  19  0.717566     19            cp  0.10     0.9538
# 257  conv1  44  0.679841     44            cp  0.10     0.9560
# 258  conv2  15  0.508273     15        tucker  0.50     0.9538
# 259  conv2  63  0.291686     63            cp  0.25     0.9570
#
#      valid_acc_before_ft  n_param_fact  test_acc  ...   norm_diff  \
# 0                 0.9560      10878589    0.9445  ...   73.751099
# 1                 0.9566      10878297    0.9448  ...   69.962518
# 2                 0.9512      11098445    0.9451  ...  118.639486
# 3                 0.9534      11136896    0.9453  ...   82.524876
# 4                 0.9526      11145261    0.9443  ...   84.728561
# ..                   ...           ...       ...  ...         ...
# 255               0.9564      10878297    0.9448  ...   70.036598
# 256               0.9516      11106445    0.9424  ...  259.904748
# 257               0.9544      10642152    0.9446  ...  254.205016
# 258               0.9532      11154645    0.9452  ...   99.056853
# 259               0.9568       9404277    0.9449  ...   27.339350
#
#           norm_b      n_b  relative_norm  scaled_norm    fact_rank  \
# 0     441.326247   4096.0       0.167286     0.018006   tucker-0.5
# 1     861.984651   4096.0       0.081277     0.017081       cp-0.5
# 2     420.734193   6272.0       0.282127     0.018916   tucker-0.5
# 3     420.734193   6272.0       0.196265     0.013158  tucker-0.75
# 4     366.026601  12544.0       0.231576     0.006755      cp-0.25
# ..           ...      ...            ...          ...          ...
# 255   861.984651   4096.0       0.081364     0.017099       cp-0.5
# 256   687.880548   6272.0       0.378831     0.041439       cp-0.1
# 257   861.984651   4096.0       0.295104     0.062062       cp-0.1
# 258   366.026601  12544.0       0.270699     0.007897   tucker-0.5
# 259  1897.313033   2048.0       0.014460     0.013349      cp-0.25
#
#      fact_layers layers_fact log_norm_diff log_test_acc
# 0      tucker-38   38-tucker      4.300696    -0.057100
# 1          cp-44       44-cp      4.247960    -0.056782
# 2      tucker-28   28-tucker      4.776089    -0.056465
# 3      tucker-28   28-tucker      4.413100    -0.056253
# 4          cp-15       15-cp      4.439453    -0.057311
# ..           ...         ...           ...          ...
# 255        cp-44       44-cp      4.249018    -0.056782
# 256        cp-19       19-cp      5.560315    -0.059325
# 257        cp-44       44-cp      5.538141    -0.056994
# 258    tucker-15   15-tucker      4.595694    -0.056359
# 259        cp-63       63-cp      3.308327    -0.056676
#
# [260 rows x 22 columns]

# %% [markdown]
# # Kendals tau
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kendalltau.html

# %%
def p_to_asterisks(p):
    """
    Estimates are significantly different from zero at 1\% significance level, 
    unless they are indicated with asterisk(s), 5\% (*), or 10\% (**), 
    or not significantly different from zero (***).
    """
    if p < 0.01:
        asterisk = ""
    elif p < 0.05:
        asterisk = "*"
    elif p < 0.1:
        asterisk = "**"
    else:
        asterisk = "***"
    return asterisk

# %%
from scipy.stats import kendalltau

# scipy.stats.kendalltau(x, y, initial_lexsort=None, nan_policy='propagate', method='auto', variant='b', alternative='two-sided')

# TODO: make multilevel columns 
# https://stackoverflow.com/questions/21443963/pandas-multilevel-column-names

errors = ['error', 'relative_norm','scaled_norm','norm_diff']
metrics = ['valid_acc_before_ft','valid_acc','test_acc']

df_kt = pd.DataFrame(index=metrics, columns=errors)

for error in errors:
    for metric in metrics:
        corr, p = kendalltau(df[error], df[metric])
        df_kt[error][metric] = "{:.2f}{}".format(corr,p_to_asterisks(p))

# %%
from scipy.stats import kendalltau

# scipy.stats.kendalltau(x, y, initial_lexsort=None, nan_policy='propagate', method='auto', variant='b', alternative='two-sided')

# TODO: make multilevel columns 
# https://stackoverflow.com/questions/21443963/pandas-multilevel-column-names

# errors = ['error', 'relative_norm','scaled_norm','norm_diff']
# metrics = ['valid_acc_before_ft','valid_acc','test_acc']

# columns = []
# for error in errors:
#     columns.append(f'{error}_tau')
#     columns.append(f'{error}_p')

# df_kt = pd.DataFrame(index=metrics, columns=errors)

# for error in errors:
#     for metric in metrics:
#         corr, p = kendalltau(df[error], df[metric])
#         df_kt[f'{error}_tau'][metric] = corr
#         df_kt[f'{error}_p'][metric] = p

# %%
neat_table_indices = {
    'valid_acc_before_ft': "Val. before f.t.",
    'valid_acc': "Val. after f.t.",
    'test_acc': "Test after f.t.",
}
neat_table_columns = {
    'error': "Relative-weights",
    'relative_norm': "Relative-features",
    'scaled_norm': "Scaled-features",
    'norm_diff': "Difference-features"}
df_kt.rename(index=neat_table_indices,columns=neat_table_columns, inplace=True)
df_kt
# Out:
#                  Relative-weights Relative-features Scaled-features  \
# Val. before f.t.            -0.61             -0.70           -0.11
# Val. after f.t.             -0.55             -0.61         -0.08**
# Test after f.t.            -0.10*            -0.09*        -0.05***
#
#                  Difference-features
# Val. before f.t.               -0.51
# Val. after f.t.                -0.44
# Test after f.t.                -0.20

# %%
print(df_kt.to_latex(
    # float_format="{:0.2f}".format, 
    position='htbp', 
    caption="Kendall's tau from ResNet-18 on Fashion-MNIST for different combinations approximation errors and performance measures. The rows correspond to accuracies measured on the validation (Val.) and test set, before and after fine-tuning (f.t.). The norms on the features are based on the training features. The relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively. All are significantly different from zero at 1\% significance level.",
    label='tab:kt_rn18_fm_errors_performances',
))
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Kendall's tau from ResNet-18 on Fashion-MNIST for different combinations approximation errors and performance measures. The rows correspond to accuracies measured on the validation (Val.) and test set, before and after fine-tuning (f.t.). The norms on the features are based on the training features. The relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively. All are significantly different from zero at 1\% significance level.}
# \label{tab:kt_rn18_fm_errors_performances}
# \begin{tabular}{lllll}
# \toprule
# {} & Relative-weights & Relative-features & Scaled-features & Difference-features \\
# \midrule
# Val. before f.t. &            -0.61 &             -0.70 &           -0.11 &               -0.51 \\
# Val. after f.t.  &            -0.55 &             -0.61 &         -0.08** &               -0.44 \\
# Test after f.t.  &           -0.10* &            -0.09* &        -0.05*** &               -0.20 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df.layers.astype(str).unique()
# Out:
# array(['38', '44', '28', '15', '19', '41', '60', '63'], dtype=object)

# %%
errors_metrics = []

for error in errors:
    for metric in metrics:
        errors_metrics.append(f'{error}-{metric}')

layers = ['15','19','28','38','41','44','60','63']

df_kt_layers = pd.DataFrame(
    index=errors_metrics,
    columns=layers,
)

for layer in df.layers.unique():
    df_layer = df[df.layers==layer]
    for error in errors:
        for metric in metrics:
            corr, p = kendalltau(df_layer[error], df_layer[metric])
            df_kt_layers[str(layer)][f'{error}-{metric}'] = "{:.2f}{}".format(corr,p_to_asterisks(p))

# %%
neat_table_indices_layers = {
    'error-valid_acc_before_ft': "Val. before f.t.-weight",
    'error-valid_acc': "Val. after f.t.-weight",
    'error-test_acc': "Test after f.t.-weight",

    'relative_norm-valid_acc_before_ft': "Val. before f.t.-rel. feat.",
    'relative_norm-valid_acc': "Val. after f.t.-rel. feat.",
    'relative_norm-test_acc': "Test after f.t.-rel. feat.",

    'scaled_norm-valid_acc_before_ft': "Val. before f.t.-sc. feat",
    'scaled_norm-valid_acc': "Val. after f.t.-sc. feat",
    'scaled_norm-test_acc': "Test after f.t.-sc. feat",

    'norm_diff-valid_acc_before_ft': "Val. before f.t.-diff. feat",
    'norm_diff-valid_acc': "Val. after f.t.-diff. feat",
    'norm_diff-test_acc': "Test after f.t.-diff. feat",
}

df_kt_layers.rename(index=neat_table_indices_layers, inplace=True)
df_kt_layers
# Out:
#                                 15     19     28     38     41        44  \
# Val. before f.t.-weight      -0.81  -0.81  -0.86  -0.72  -0.86     -0.65
# Val. after f.t.-weight       -0.77  -0.59  -0.77  -0.55  -0.85     -0.43
# Test after f.t.-weight       -0.58  -0.59  -0.45   0.36  -0.36  -0.10***
# Val. before f.t.-rel. feat.  -0.85  -0.83  -0.84  -0.69  -0.84     -0.64
# Val. after f.t.-rel. feat.   -0.79  -0.62  -0.73  -0.52  -0.81     -0.40
# Test after f.t.-rel. feat.   -0.52  -0.66  -0.43   0.34  -0.36  -0.08***
# Val. before f.t.-sc. feat    -0.85  -0.83  -0.84  -0.69  -0.84     -0.64
# Val. after f.t.-sc. feat     -0.79  -0.62  -0.73  -0.52  -0.81     -0.40
# Test after f.t.-sc. feat     -0.52  -0.66  -0.43   0.34  -0.36  -0.08***
# Val. before f.t.-diff. feat  -0.85  -0.83  -0.84  -0.69  -0.84     -0.64
# Val. after f.t.-diff. feat   -0.79  -0.62  -0.73  -0.52  -0.81     -0.40
# Test after f.t.-diff. feat   -0.52  -0.66  -0.43   0.34  -0.36  -0.08***
#
#                                    60        63
# Val. before f.t.-weight          0.48    nan***
# Val. after f.t.-weight       -0.08***   0.19***
# Test after f.t.-weight        0.04***   0.00***
# Val. before f.t.-rel. feat.      0.59    nan***
# Val. after f.t.-rel. feat.   -0.05***   0.18***
# Test after f.t.-rel. feat.    0.05***  -0.01***
# Val. before f.t.-sc. feat        0.59    nan***
# Val. after f.t.-sc. feat     -0.05***   0.18***
# Test after f.t.-sc. feat      0.05***  -0.01***
# Val. before f.t.-diff. feat      0.59    nan***
# Val. after f.t.-diff. feat   -0.05***   0.18***
# Test after f.t.-diff. feat    0.05***  -0.01***

# %%
print(df_kt_layers.to_latex(
    position='htbp', 
    caption="Kendall's tau from ResNet-18 on Fashion-MNIST conditioned on the layer for different combinations approximation errors and performance measures. The rows correspond to combinations of accuracies (measured on the validation (Val.) and test set, before and after fine-tuning (f.t.)) and approximation errors (relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively). The norms on the features are based on the training features. Estimates are significantly different from zero at 1\% significance level, unless they are indicated with asterisk(s), 5\% (*), or 10\% (**), or not significantly different from zero (***).",
    label='tab:kt_rn18_c10_errors_performances_layers',
))
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Kendall's tau from ResNet-18 on Fashion-MNIST conditioned on the layer for different combinations approximation errors and performance measures. The rows correspond to combinations of accuracies (measured on the validation (Val.) and test set, before and after fine-tuning (f.t.)) and approximation errors (relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively). The norms on the features are based on the training features. Estimates are significantly different from zero at 1\% significance level, unless they are indicated with asterisk(s), 5\% (*), or 10\% (**), or not significantly different from zero (***).}
# \label{tab:kt_rn18_c10_errors_performances_layers}
# \begin{tabular}{lllllllll}
# \toprule
# {} &     15 &     19 &     28 &     38 &     41 &        44 &        60 &        63 \\
# \midrule
# Val. before f.t.-weight     &  -0.81 &  -0.81 &  -0.86 &  -0.72 &  -0.86 &     -0.65 &      0.48 &    nan*** \\
# Val. after f.t.-weight      &  -0.77 &  -0.59 &  -0.77 &  -0.55 &  -0.85 &     -0.43 &  -0.08*** &   0.19*** \\
# Test after f.t.-weight      &  -0.58 &  -0.59 &  -0.45 &   0.36 &  -0.36 &  -0.10*** &   0.04*** &   0.00*** \\
# Val. before f.t.-rel. feat. &  -0.85 &  -0.83 &  -0.84 &  -0.69 &  -0.84 &     -0.64 &      0.59 &    nan*** \\
# Val. after f.t.-rel. feat.  &  -0.79 &  -0.62 &  -0.73 &  -0.52 &  -0.81 &     -0.40 &  -0.05*** &   0.18*** \\
# Test after f.t.-rel. feat.  &  -0.52 &  -0.66 &  -0.43 &   0.34 &  -0.36 &  -0.08*** &   0.05*** &  -0.01*** \\
# Val. before f.t.-sc. feat   &  -0.85 &  -0.83 &  -0.84 &  -0.69 &  -0.84 &     -0.64 &      0.59 &    nan*** \\
# Val. after f.t.-sc. feat    &  -0.79 &  -0.62 &  -0.73 &  -0.52 &  -0.81 &     -0.40 &  -0.05*** &   0.18*** \\
# Test after f.t.-sc. feat    &  -0.52 &  -0.66 &  -0.43 &   0.34 &  -0.36 &  -0.08*** &   0.05*** &  -0.01*** \\
# Val. before f.t.-diff. feat &  -0.85 &  -0.83 &  -0.84 &  -0.69 &  -0.84 &     -0.64 &      0.59 &    nan*** \\
# Val. after f.t.-diff. feat  &  -0.79 &  -0.62 &  -0.73 &  -0.52 &  -0.81 &     -0.40 &  -0.05*** &   0.18*** \\
# Test after f.t.-diff. feat  &  -0.52 &  -0.66 &  -0.43 &   0.34 &  -0.36 &  -0.08*** &   0.05*** &  -0.01*** \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df.factorization.unique()
# Out:
# array(['tucker', 'cp'], dtype=object)

# %%
factorizations = ['cp', 'tucker']

df_kt_factorizations = pd.DataFrame(
    index=errors_metrics,
    columns=factorizations,
)

for fact in df.factorization.unique():
    df_ = df[df.factorization==fact]
    for error in errors:
        for metric in metrics:
            corr, p = kendalltau(df_[error], df_[metric])
            df_kt_factorizations[str(fact)][f'{error}-{metric}'] = "{:.2f}{}".format(corr,p_to_asterisks(p))

df_kt_factorizations.rename(index=neat_table_indices_layers, inplace=True)

print(df_kt_factorizations.to_latex(
    position='htbp', 
    caption="Kendall's tau from ResNet-18 on Fashion-MNIST conditioned on the factorization for different combinations approximation errors and performance measures. The rows correspond to combinations of accuracies (measured on the validation (Val.) and test set, before and after fine-tuning (f.t.)) and approximation errors (relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively). The norms on the features are based on the training features. Estimates are significantly different from zero at 1\% significance level, unless they are indicated with asterisk(s), 5\% (*), or 10\% (**), or not significantly different from zero (***).",
    label='kt_rn18_fm_errors_performances_factorization',
))
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Kendall's tau from ResNet-18 on Fashion-MNIST conditioned on the factorization for different combinations approximation errors and performance measures. The rows correspond to combinations of accuracies (measured on the validation (Val.) and test set, before and after fine-tuning (f.t.)) and approximation errors (relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively). The norms on the features are based on the training features. Estimates are significantly different from zero at 1\% significance level, unless they are indicated with asterisk(s), 5\% (*), or 10\% (**), or not significantly different from zero (***).}
# \label{kt_rn18_fm_errors_performances_factorization}
# \begin{tabular}{lll}
# \toprule
# {} &        cp &    tucker \\
# \midrule
# Val. before f.t.-weight     &     -0.61 &     -0.62 \\
# Val. after f.t.-weight      &     -0.56 &     -0.53 \\
# Test after f.t.-weight      &  -0.07*** &     -0.16 \\
# Val. before f.t.-rel. feat. &     -0.69 &     -0.67 \\
# Val. after f.t.-rel. feat.  &     -0.62 &     -0.58 \\
# Test after f.t.-rel. feat.  &  -0.08*** &   -0.11** \\
# Val. before f.t.-sc. feat   &   -0.11** &  -0.06*** \\
# Val. after f.t.-sc. feat    &    -0.14* &   0.05*** \\
# Test after f.t.-sc. feat    &   0.01*** &   -0.11** \\
# Val. before f.t.-diff. feat &     -0.48 &     -0.52 \\
# Val. after f.t.-diff. feat  &     -0.46 &     -0.39 \\
# Test after f.t.-diff. feat  &    -0.15* &     -0.28 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # Pearson Correlation
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html

# %%
from scipy.stats import pearsonr

# scipy.stats.kendalltau(x, y, initial_lexsort=None, nan_policy='propagate', method='auto', variant='b', alternative='two-sided')

errors = ['error', 'relative_norm','scaled_norm','norm_diff']
metrics = ['valid_acc_before_ft','valid_acc','test_acc']

df_pr = pd.DataFrame(index=metrics, columns=errors)

for error in errors:
    for metric in metrics:
        corr, p = pearsonr(df[error], df[metric])
        df_pr[error][metric] = corr

# %%
df_pr.rename(index=neat_table_indices,columns=neat_table_columns, inplace=True)

print(df_kt.to_latex(
    float_format="{:0.2f}".format, 
    position='htbp', 
    caption="Pearson's rho from ResNet18 on CIFAR10 for different combinations approximation errors and performance measures. The rows correspond to accuracies measured on the validation (Val.) and test set, before and after fine-tuning (f.t.). The norms on the features are based on the training features. The relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively. All are significantly different from zero at 1\% significance level.",
    label='pr_rn18_c10_errors_performances',
))
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Pearson's rho from ResNet18 on CIFAR10 for different combinations approximation errors and performance measures. The rows correspond to accuracies measured on the validation (Val.) and test set, before and after fine-tuning (f.t.). The norms on the features are based on the training features. The relative, scaled, and difference norms correspond to Eq. (3), (2), and (1) respectively. All are significantly different from zero at 1\% significance level.}
# \label{pr_rn18_c10_errors_performances}
# \begin{tabular}{lllll}
# \toprule
# {} & Relative-weights & Relative-features & Scaled-features & Difference-features \\
# \midrule
# Val. before f.t. &            -0.61 &             -0.70 &           -0.11 &               -0.51 \\
# Val. after f.t.  &            -0.55 &             -0.61 &         -0.08** &               -0.44 \\
# Test after f.t.  &           -0.10* &            -0.09* &        -0.05*** &               -0.20 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_pr_layers = pd.DataFrame(
    index=layers,
    columns=errors_metrics,
)

for layer in df.layers.unique():
    df_layer = df[df.layers==layer]
    for error in errors:
        for metric in metrics:
            corr, p = pearsonr(df_layer[error], df_layer[metric])
            df_pr_layers[f'{error}-{metric}'][str(layer)] = (corr, p)
# Out:
# /home/jetzeschuurman/gitProjects/phd/tddl/venv/lib/python3.8/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
df_pr_layers
# Out:
#                         error-valid_acc_before_ft  \
# 15   (-0.8957189701272898, 2.304202892168081e-11)
# 19  (-0.7984641121101603, 1.2413415595392639e-07)
# 28   (-0.9076978843745694, 9.921758711187963e-20)
# 38   (-0.8334321963069545, 1.085013723149495e-08)
# 41   (-0.9188918148231305, 7.910443901051673e-13)
# 44   (-0.8363815899903435, 8.613652706053538e-09)
# 60     (0.663148681437422, 6.503489174040834e-05)
# 63                                     (nan, nan)
#
#                                   error-valid_acc  \
# 15  (-0.9068071044125261, 5.1232485878233485e-12)
# 19   (-0.8416821596311995, 5.623157058194137e-09)
# 28   (-0.9321302448153267, 8.191884266216285e-23)
# 38   (-0.7355001622106941, 3.649536506311719e-06)
# 41   (-0.9621035662741438, 2.446754598223532e-17)
# 44  (-0.6309927957635759, 0.00018514550431938267)
# 60    (-0.004122435381511071, 0.9827509911127151)
# 63      (0.22306478499713023, 0.2360719129863939)
#
#                                    error-test_acc  \
# 15  (-0.8273101517919397, 1.7277124442543163e-08)
# 19  (-0.7848599335029599, 2.8289364183215665e-07)
# 28  (-0.7287907778981914, 1.9688478525116893e-09)
# 38     (0.4835400828195008, 0.006788339839189428)
# 41     (-0.457187422225917, 0.011085024481492378)
# 44       (0.0737268614631858, 0.6986174502812549)
# 60      (0.06963942195168232, 0.7146130659541493)
# 63       (0.1322560411245307, 0.4859997567949886)
#
#                 relative_norm-valid_acc_before_ft  \
# 15   (-0.9420941168118128, 8.174754796059022e-15)
# 19   (-0.875576073625972, 2.4011705076789573e-10)
# 28  (-0.9434130135914474, 1.1859024212506211e-24)
# 38   (-0.7711119057565932, 6.139599819888966e-07)
# 41  (-0.9372141453244792, 2.4615802036642064e-14)
# 44    (-0.8613605719621503, 9.96401977743831e-10)
# 60   (0.7509207860657079, 1.7488502249332691e-06)
# 63                                     (nan, nan)
#
#                           relative_norm-valid_acc  \
# 15  (-0.9540507612502881, 3.4553632911438877e-16)
# 19    (-0.82727118543359, 1.7327351405375284e-08)
# 28   (-0.9395877901139772, 5.457510606909956e-24)
# 38   (-0.6444460765434653, 0.0001212628558465733)
# 41   (-0.9668883178246346, 3.808535770983737e-18)
# 44   (-0.6065902235010444, 0.0003801059474927901)
# 60      (0.035951746854349036, 0.850399064195509)
# 63     (0.22587032120505984, 0.23007712929883198)
#
#                            relative_norm-test_acc  \
# 15   (-0.8258141236808532, 1.930419768187441e-08)
# 19  (-0.8531071895905187, 2.1224115516632232e-09)
# 28   (-0.7739673364608713, 4.360133842505143e-11)
# 38   (0.49269232551158293, 0.0056740112684628054)
# 41    (-0.5004139879570589, 0.004858925683441144)
# 44      (0.04632381548191221, 0.8079472366395766)
# 60      (0.09566573175962627, 0.6150529300978617)
# 63      (0.16174887494971524, 0.3931416389397014)
#
#                   scaled_norm-valid_acc_before_ft  \
# 15    (-0.942016029946895, 8.326398897534736e-15)
# 19   (-0.8757298721611269, 2.362280248301798e-10)
# 28  (-0.9434365840987226, 1.1744175059454317e-24)
# 38   (-0.7711424720617202, 6.129393794319952e-07)
# 41   (-0.937302553420654, 2.4148277094688903e-14)
# 44   (-0.8614542382586104, 9.876160883068278e-10)
# 60   (0.7508050608502571, 1.7588743697933811e-06)
# 63                                     (nan, nan)
#
#                             scaled_norm-valid_acc  \
# 15   (-0.9539918469550551, 3.516624367691685e-16)
# 19  (-0.8272218566790575, 1.7391126909601703e-08)
# 28   (-0.9396030228000046, 5.425518596416293e-24)
# 38  (-0.6444391168330234, 0.00012129003921128792)
# 41  (-0.9668909273415921, 3.8043969563743675e-18)
# 44   (-0.6066768548811025, 0.0003791756933353342)
# 60      (0.03598563464478417, 0.8502596276796681)
# 63     (0.22649209931210407, 0.22876251359803698)
#
#                              scaled_norm-test_acc  \
# 15  (-0.8258503765870316, 1.9252608672284956e-08)
# 19   (-0.8532912791447854, 2.087966190103543e-09)
# 28   (-0.7740399943758309, 4.330494509686447e-11)
# 38   (0.49269935920313984, 0.0056732188724656785)
# 41   (-0.5006746836418886, 0.0048332529872078716)
# 44       (0.04643992168251218, 0.807474805135601)
# 60      (0.09571686554455155, 0.6148630785239049)
# 63        (0.1619595863151672, 0.392517249086684)
#
#                     norm_diff-valid_acc_before_ft  \
# 15    (-0.942016029946895, 8.326398897534736e-15)
# 19   (-0.8757298721611269, 2.362280248301798e-10)
# 28  (-0.9434365840987226, 1.1744175059454317e-24)
# 38   (-0.7711424720617202, 6.129393794319952e-07)
# 41   (-0.937302553420654, 2.4148277094688903e-14)
# 44   (-0.8614542382586104, 9.876160883068278e-10)
# 60   (0.7508050608502571, 1.7588743697933811e-06)
# 63                                     (nan, nan)
#
#                               norm_diff-valid_acc  \
# 15   (-0.9539918469550551, 3.516624367691685e-16)
# 19  (-0.8272218566790575, 1.7391126909601703e-08)
# 28   (-0.9396030228000046, 5.425518596416293e-24)
# 38  (-0.6444391168330234, 0.00012129003921128792)
# 41  (-0.9668909273415921, 3.8043969563743675e-18)
# 44   (-0.6066768548811025, 0.0003791756933353342)
# 60      (0.03598563464478417, 0.8502596276796681)
# 63     (0.22649209931210407, 0.22876251359803698)
#
#                               norm_diff-test_acc
# 15  (-0.8258503765870318, 1.925260867228478e-08)
# 19  (-0.8532912791447854, 2.087966190103543e-09)
# 28   (-0.774039994375831, 4.330494509686409e-11)
# 38  (0.49269935920313984, 0.0056732188724656785)
# 41  (-0.5006746836418886, 0.0048332529872078716)
# 44      (0.04643992168251218, 0.807474805135601)
# 60     (0.09571686554455155, 0.6148630785239049)
# 63       (0.1619595863151672, 0.392517249086684)

# %%
g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm","norm_diff" ,"log_norm_diff"],
    hue="layers",
    height=4,
    # style="factorization",
) #, height=4)
g.map(sns.regplot) # color=".3")
g.set(ylim=ylim)
# g.set(ylim=(-1, 11), yticks=[0, 5, 10])
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(5):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

g.savefig("../../plots/fmnist/rn18/rn18_fm_linear_errors_performances_layers")

# %%
g = sns.PairGrid(
    df,
    y_vars=["valid_acc_before_ft", "valid_acc","test_acc"], 
    x_vars=["error", "relative_norm", "scaled_norm" ,"norm_diff","log_norm_diff"],
    hue="layers",
    height=4,
    # style="factorization",
) #, height=4)
g.map(lambda x, y, **kwargs: sns.regplot(x=x,y=y,order=2)) # sns.scatterplot(x=x,y=y,hue=df.layers,style=df.factorization,legend='auto')
g.set(ylim=(0.86,0.925))
# g.set(ylim=(-1, 11), yticks=[0, 5, 10])
g.add_legend()

lines = {
    0: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    1: {
        "y":baseline_result['best_valid_acc'],
        "color":'black',
    },
    2: {
        "y":baseline_result['test_acc'],
        "color":'black',
    },
}

for i in range(3):
    for j in range(5):
        gax = g.axes[i][j]
        gax.axhline(**(lines[i]))
        xlabel = gax.get_xlabel()
        ylabel = gax.get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

# plt.legend(
#     bbox_to_anchor=(1.05, 1,1,1),
#     loc='upper left', borderaxespad=0.
# )
g.savefig("../../plots/fmnist/rn18/rn18_fm_poly2_errors_performances_layers")

# %%
from statsmodels.api import OLS

errors = ['error', 'relative_norm','scaled_norm','norm_diff']
metrics = ['valid_acc_before_ft','valid_acc','test_acc']

df_ols = pd.DataFrame(index=metrics, columns=errors)

for error in errors:
    for metric in metrics:
        res = OLS(df[metric], df[error], hasconst=True).fit()
        print(res.summary())
        # df_kt[error][metric] = (corr, p)
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     valid_acc_before_ft   R-squared:                   -1149.942
# Model:                             OLS   Adj. R-squared:              -1149.942
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                         14:15:12   Log-Likelihood:                -109.90
# No. Observations:                  260   AIC:                             221.8
# Df Residuals:                      259   BIC:                             225.4
# Df Model:                            0
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# error          1.5496      0.043     36.461      0.000       1.466       1.633
# ==============================================================================
# Omnibus:                      151.241   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.750
# Skew:                          -0.121   Prob(JB):                     0.000231
# Kurtosis:                       1.780   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              valid_acc   R-squared:                   -8804.910
# Model:                            OLS   Adj. R-squared:              -8804.910
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -107.89
# No. Observations:                 260   AIC:                             217.8
# Df Residuals:                     259   BIC:                             221.3
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# error          1.5599      0.042     36.988      0.000       1.477       1.643
# ==============================================================================
# Omnibus:                      157.919   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.780
# Skew:                          -0.105   Prob(JB):                     0.000227
# Kurtosis:                       1.773   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               test_acc   R-squared:                  -12724.554
# Model:                            OLS   Adj. R-squared:             -12724.554
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -106.07
# No. Observations:                 260   AIC:                             214.1
# Df Residuals:                     259   BIC:                             217.7
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# error          1.5504      0.042     37.021      0.000       1.468       1.633
# ==============================================================================
# Omnibus:                      155.456   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.735
# Skew:                          -0.107   Prob(JB):                     0.000232
# Kurtosis:                       1.776   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     valid_acc_before_ft   R-squared:                   -2900.713
# Model:                             OLS   Adj. R-squared:              -2900.713
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                         14:15:12   Log-Likelihood:                -230.11
# No. Observations:                  260   AIC:                             462.2
# Df Residuals:                      259   BIC:                             465.8
# Df Model:                            0
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# relative_norm     2.2324      0.116     19.262      0.000       2.004       2.461
# ==============================================================================
# Omnibus:                       22.178   Durbin-Watson:                   1.230
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.780
# Skew:                          -0.769   Prob(JB):                     2.52e-06
# Kurtosis:                       3.125   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              valid_acc   R-squared:                  -22481.337
# Model:                            OLS   Adj. R-squared:             -22481.337
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -229.74
# No. Observations:                 260   AIC:                             461.5
# Df Residuals:                     259   BIC:                             465.0
# Df Model:                           0
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# relative_norm     2.2510      0.116     19.450      0.000       2.023       2.479
# ==============================================================================
# Omnibus:                       22.654   Durbin-Watson:                   1.230
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.353
# Skew:                          -0.775   Prob(JB):                     1.89e-06
# Kurtosis:                       3.165   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               test_acc   R-squared:                  -32524.901
# Model:                            OLS   Adj. R-squared:             -32524.901
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -228.07
# No. Observations:                 260   AIC:                             458.1
# Df Residuals:                     259   BIC:                             461.7
# Df Model:                           0
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# relative_norm     2.2372      0.115     19.456      0.000       2.011       2.464
# ==============================================================================
# Omnibus:                       22.911   Durbin-Watson:                   1.230
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.695
# Skew:                          -0.780   Prob(JB):                     1.60e-06
# Kurtosis:                       3.174   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     valid_acc_before_ft   R-squared:                   -2601.039
# Model:                             OLS   Adj. R-squared:              -2601.039
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                         14:15:12   Log-Likelihood:                -215.94
# No. Observations:                  260   AIC:                             433.9
# Df Residuals:                      259   BIC:                             437.4
# Df Model:                            0
# Covariance Type:             nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# scaled_norm    22.5970      1.073     21.061      0.000      20.484      24.710
# ==============================================================================
# Omnibus:                       48.926   Durbin-Watson:                   1.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.041
# Skew:                          -1.148   Prob(JB):                     2.27e-16
# Kurtosis:                       4.173   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              valid_acc   R-squared:                  -20147.487
# Model:                            OLS   Adj. R-squared:             -20147.487
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -215.50
# No. Observations:                 260   AIC:                             433.0
# Df Residuals:                     259   BIC:                             436.6
# Df Model:                           0
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# scaled_norm    22.7745      1.071     21.263      0.000      20.665      24.884
# ==============================================================================
# Omnibus:                       48.093   Durbin-Watson:                   1.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.078
# Skew:                          -1.140   Prob(JB):                     6.06e-16
# Kurtosis:                       4.127   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               test_acc   R-squared:                  -29120.613
# Model:                            OLS   Adj. R-squared:             -29120.613
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -213.69
# No. Observations:                 260   AIC:                             429.4
# Df Residuals:                     259   BIC:                             432.9
# Df Model:                           0
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# scaled_norm    22.6409      1.064     21.286      0.000      20.546      24.735
# ==============================================================================
# Omnibus:                       48.097   Durbin-Watson:                   1.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.093
# Skew:                          -1.140   Prob(JB):                     6.02e-16
# Kurtosis:                       4.128   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     valid_acc_before_ft   R-squared:                   -3320.822
# Model:                             OLS   Adj. R-squared:              -3320.822
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                         14:15:12   Log-Likelihood:                -247.69
# No. Observations:                  260   AIC:                             497.4
# Df Residuals:                      259   BIC:                             500.9
# Df Model:                            0
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# norm_diff      0.0032      0.000     17.069      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                      106.020   Durbin-Watson:                   1.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              327.855
# Skew:                          -1.818   Prob(JB):                     6.42e-72
# Kurtosis:                       7.128   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              valid_acc   R-squared:                  -25678.521
# Model:                            OLS   Adj. R-squared:             -25678.521
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -247.03
# No. Observations:                 260   AIC:                             496.1
# Df Residuals:                     259   BIC:                             499.6
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# norm_diff      0.0032      0.000     17.291      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                      105.696   Durbin-Watson:                   1.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              325.938
# Skew:                          -1.814   Prob(JB):                     1.67e-71
# Kurtosis:                       7.115   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               test_acc   R-squared:                  -37096.910
# Model:                            OLS   Adj. R-squared:             -37096.910
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):                nan
# Time:                        14:15:12   Log-Likelihood:                -245.16
# No. Observations:                 260   AIC:                             492.3
# Df Residuals:                     259   BIC:                             495.9
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# norm_diff      0.0032      0.000     17.320      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                      105.921   Durbin-Watson:                   1.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              327.773
# Skew:                          -1.816   Prob(JB):                     6.68e-72
# Kurtosis:                       7.131   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_pr_layers = pd.DataFrame(
    index=layers,
    columns=errors_metrics,
)

for layer in df.layers.unique():
    df_layer = df[df.layers==layer]
    for error in errors:
        for metric in metrics:
            corr, p = pearsonr(df_layer[error], df_layer[metric])
            df_pr_layers[f'{error}-{metric}'][str(layer)] = (corr, p)
# Out:
# /home/jetzeschuurman/gitProjects/phd/tddl/venv/lib/python3.8/site-packages/scipy/stats/stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
df_pr_layers
# Out:
#                         error-valid_acc_before_ft  \
# 63                                     (nan, nan)
# 60                                     (nan, nan)
# 28   (-0.8473943846363547, 8.526029318429482e-15)
# 44    (-0.92807967008753, 1.5569321880360468e-13)
# 15  (-0.8452560604640299, 4.1808353690622275e-09)
# 38    (-0.865389039933643, 6.767629125830957e-10)
# 41   (-0.9703158826938701, 8.423955171813325e-19)
# 19   (-0.8860065078609245, 7.535093163088947e-11)
#
#                                   error-valid_acc  \
# 63      (0.2879151138321128, 0.12286811404521604)
# 60      (0.05364974643058675, 0.7782745727113813)
# 28     (-0.89963258051531, 6.749407186012029e-19)
# 44   (-0.6504162560386235, 9.984548200024738e-05)
# 15  (-0.8308757372821841, 1.3206059307718488e-08)
# 38   (-0.6776279241263408, 3.895111656379433e-05)
# 41  (-0.7495675516016722, 1.8693704254260377e-06)
# 19   (-0.9112030273968714, 2.678090326834498e-12)
#
#                                    error-test_acc  \
# 63      (0.08140949047449081, 0.6688969781722545)
# 60      (-0.202319015036619, 0.28363153595318413)
# 28   (-0.8503506557583609, 5.521851294743111e-15)
# 44   (-0.40001403206557967, 0.028506973055201903)
# 15   (-0.778557370077811, 4.0628161410152266e-07)
# 38    (-0.5044203224748514, 0.004476991652362888)
# 41   (-0.8643378889684963, 7.495257969083912e-10)
# 19  (-0.7977242458237551, 1.3002694977976146e-07)
#
#                 relative_norm-valid_acc_before_ft  \
# 63                                     (nan, nan)
# 60                                     (nan, nan)
# 28     (-0.9120220389779395, 3.2969719058788e-20)
# 44    (-0.9426384838741954, 7.18649942865184e-15)
# 15    (-0.9041877267765982, 7.42816655433022e-12)
# 38   (-0.8635795042211782, 8.064108376976551e-10)
# 41  (-0.9941407242821838, 1.3281946044565624e-28)
# 19   (-0.9543004542805604, 3.206527864443561e-16)
#
#                           relative_norm-valid_acc  \
# 63      (0.22660045854936292, 0.2285339296372333)
# 60     (-0.07591620160216175, 0.6901010135920719)
# 28   (-0.9501238765400875, 6.183917885757045e-26)
# 44  (-0.6841285370782828, 3.0657713149688406e-05)
# 15     (-0.88880481257465, 5.416616492454828e-11)
# 38    (-0.7167802034754958, 8.35639365741935e-06)
# 41   (-0.8424403179898148, 5.283717911651034e-09)
# 19  (-0.9624158367000015, 2.1833265641118366e-17)
#
#                           relative_norm-test_acc  \
# 63     (0.08969793863827741, 0.6373750749423998)
# 60     (-0.13347274372940285, 0.481960786929708)
# 28  (-0.9094785965290709, 6.345321235786794e-20)
# 44  (-0.43789598452890244, 0.015512948579349773)
# 15  (-0.8428099291664479, 5.125140529275926e-09)
# 38  (-0.48123306693167356, 0.007096860612639137)
# 41   (-0.885164202369319, 8.308319981602859e-11)
# 19  (-0.875381953010202, 2.4510970789238774e-10)
#
#                   scaled_norm-valid_acc_before_ft  \
# 63                                     (nan, nan)
# 60                                     (nan, nan)
# 28   (-0.9120504145735633, 3.272613774020444e-20)
# 44   (-0.9426349991137994, 7.192458046807915e-15)
# 15   (-0.9042329237813166, 7.381372629649023e-12)
# 38   (-0.8635896750238307, 8.056224123315002e-10)
# 41  (-0.9941311159924484, 1.3589347640551856e-28)
# 19  (-0.9542604206055397, 3.2452737999364755e-16)
#
#                             scaled_norm-valid_acc  \
# 63     (0.22549585148419915, 0.23087130977122738)
# 60     (-0.07619222745748086, 0.6890298881252326)
# 28   (-0.9501462603759921, 6.119201642748657e-26)
# 44   (-0.684144129964898, 3.0639890645477375e-05)
# 15   (-0.8888088544663618, 5.414000236015289e-11)
# 38   (-0.7167965316315917, 8.350594812939163e-06)
# 41  (-0.8424757709014247, 5.2683145963633854e-09)
# 19   (-0.9623777391993933, 2.213995204232982e-17)
#
#                             scaled_norm-test_acc  \
# 63     (0.08987146559723141, 0.6367214748520443)
# 60     (-0.1332129890742588, 0.4828216177381716)
# 28  (-0.9095089557688517, 6.296645262386004e-20)
# 44   (-0.4379219058215649, 0.015506136280367542)
# 15  (-0.8428153045877268, 5.122866793629805e-09)
# 38  (-0.48124877796815807, 0.007094720012967866)
# 41  (-0.8851908100070819, 8.282817723520555e-11)
# 19  (-0.875322638564176, 2.4665416634320433e-10)
#
#                     norm_diff-valid_acc_before_ft  \
# 63                                     (nan, nan)
# 60                                     (nan, nan)
# 28   (-0.9120504145735633, 3.272613774020444e-20)
# 44   (-0.9426349991137994, 7.192458046807915e-15)
# 15   (-0.9042329237813166, 7.381372629649023e-12)
# 38   (-0.8635896750238307, 8.056224123315002e-10)
# 41  (-0.9941311159924484, 1.3589347640551856e-28)
# 19  (-0.9542604206055397, 3.2452737999364755e-16)
#
#                               norm_diff-valid_acc  \
# 63     (0.22549585148419915, 0.23087130977122738)
# 60     (-0.07619222745748086, 0.6890298881252326)
# 28   (-0.9501462603759921, 6.119201642748657e-26)
# 44   (-0.684144129964898, 3.0639890645477375e-05)
# 15   (-0.8888088544663618, 5.414000236015289e-11)
# 38   (-0.7167965316315917, 8.350594812939163e-06)
# 41  (-0.8424757709014247, 5.2683145963633854e-09)
# 19   (-0.9623777391993933, 2.213995204232982e-17)
#
#                               norm_diff-test_acc
# 63     (0.08987146559723141, 0.6367214748520443)
# 60     (-0.1332129890742588, 0.4828216177381716)
# 28  (-0.9095089557688517, 6.296645262386004e-20)
# 44   (-0.4379219058215649, 0.015506136280367542)
# 15  (-0.8428153045877268, 5.122866793629805e-09)
# 38  (-0.48124877796815807, 0.007094720012967866)
# 41  (-0.8851908100070819, 8.282817723520555e-11)
# 19  (-0.875322638564176, 2.4665416634320433e-10)
